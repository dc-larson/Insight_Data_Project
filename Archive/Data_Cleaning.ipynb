# %% [markdown]
# ### Data Cleaning
#
# I would like to clean data from two sources:
#
# 1) ACS 2018 Census Data
# 2) Shoemill 5-year Transaction History (By store, location, Customer, Price, etc.)

# %% [markdown]
# #### ACS 2018 Data

# %%
import pandas as pd
import numpy as np
acs_dta = pd.read_csv('acs_dta.csv')
acs_dta.head()
# Out:
#                                           Unnamed: 0  unwt_tot_pop_count  \
# 0  Block Group 1, Census Tract 16, Deschutes Coun...                50.0
# 1  Block Group 2, Census Tract 16, Deschutes Coun...               100.0
# 2  Block Group 1, Census Tract 17, Deschutes Coun...               150.0
# 3  Block Group 2, Census Tract 17, Deschutes Coun...               100.0
# 4  Block Group 4, Census Tract 17, Deschutes Coun...                90.0
#
#    tot_housing  tot_sex_age  tot_male  tot_female  tot_med_age  med_age_male  \
# 0         20.0          874       586         288         32.9          31.0
# 1         50.0         2271      1089        1182         33.5          28.1
# 2         60.0         3118      1374        1744         40.5          42.3
# 3         50.0         2370      1201        1169         37.2          34.3
# 4         40.0         2228       952        1276         32.8          37.6
#
#    med_age_female  tot_pop  hh_inc
# 0            57.0      874     374
# 1            36.8     2271     979
# 2            37.8     3118    1269
# 3            39.7     2370    1026
# 4            30.2     2228     790

# %% [markdown]
# You can see above that there is an unnamed column and I would like to break apart block group, tract, and county into columns.

# %%
acsdta_cln = acs_dta["Unnamed: 0"].str.split(",", n = 5, expand = True)

# %%
print(acsdta_cln)
# Out:
#                   0                    1                  2  \
# 0     Block Group 1      Census Tract 16   Deschutes County
# 1     Block Group 2      Census Tract 16   Deschutes County
# 2     Block Group 1      Census Tract 17   Deschutes County
# 3     Block Group 2      Census Tract 17   Deschutes County
# 4     Block Group 4      Census Tract 17   Deschutes County
# ...             ...                  ...                ...
# 1092  Block Group 2   Census Tract 67.02   Multnomah County
# 1093  Block Group 2     Census Tract 105   Multnomah County
# 1094  Block Group 1   Census Tract 82.01   Multnomah County
# 1095  Block Group 2      Census Tract 32   Multnomah County
# 1096  Block Group 3    Census Tract 4.02   Multnomah County
#
#                                 3  \
# 0      Oregon: Summary level: 150
# 1      Oregon: Summary level: 150
# 2      Oregon: Summary level: 150
# 3      Oregon: Summary level: 150
# 4      Oregon: Summary level: 150
# ...                           ...
# 1092   Oregon: Summary level: 150
# 1093   Oregon: Summary level: 150
# 1094   Oregon: Summary level: 150
# 1095   Oregon: Summary level: 150
# 1096   Oregon: Summary level: 150
#
#                                                       4
# 0      state:41> county:017> tract:001600> block gro...
# 1      state:41> county:017> tract:001600> block gro...
# 2      state:41> county:017> tract:001700> block gro...
# 3      state:41> county:017> tract:001700> block gro...
# 4      state:41> county:017> tract:001700> block gro...
# ...                                                 ...
# 1092   state:41> county:051> tract:006702> block gro...
# 1093   state:41> county:051> tract:010500> block gro...
# 1094   state:41> county:051> tract:008201> block gro...
# 1095   state:41> county:051> tract:003200> block gro...
# 1096   state:41> county:051> tract:000402> block gro...
#
# [1097 rows x 5 columns]

# %%
acsdta_cln
# Out:
# 0       [Block Group 1,  Census Tract 16,  Deschutes C...
# 1       [Block Group 2,  Census Tract 16,  Deschutes C...
# 2       [Block Group 1,  Census Tract 17,  Deschutes C...
# 3       [Block Group 2,  Census Tract 17,  Deschutes C...
# 4       [Block Group 4,  Census Tract 17,  Deschutes C...
#                               ...
# 1092    [Block Group 2,  Census Tract 67.02,  Multnoma...
# 1093    [Block Group 2,  Census Tract 105,  Multnomah ...
# 1094    [Block Group 1,  Census Tract 82.01,  Multnoma...
# 1095    [Block Group 2,  Census Tract 32,  Multnomah C...
# 1096    [Block Group 3,  Census Tract 4.02,  Multnomah...
# Name: Unnamed: 0, Length: 1097, dtype: object

# %%
#pd.options.display.max_columns = None
cols = acsdta_cln.columns.tolist()

acsdta_cln.to_csv('acsdta_cln.csv', index=True)

# %%
acsdta_cln.columns.values
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
acsdta_cln.rename(columns={'0': 'blkgrp', '1': 'tract','2':'cnty'}, inplace=True)

# %%
print(acsdta_cln)
# Out:
#                   0                    1                  2  \
# 0     Block Group 1      Census Tract 16   Deschutes County
# 1     Block Group 2      Census Tract 16   Deschutes County
# 2     Block Group 1      Census Tract 17   Deschutes County
# 3     Block Group 2      Census Tract 17   Deschutes County
# 4     Block Group 4      Census Tract 17   Deschutes County
# ...             ...                  ...                ...
# 1092  Block Group 2   Census Tract 67.02   Multnomah County
# 1093  Block Group 2     Census Tract 105   Multnomah County
# 1094  Block Group 1   Census Tract 82.01   Multnomah County
# 1095  Block Group 2      Census Tract 32   Multnomah County
# 1096  Block Group 3    Census Tract 4.02   Multnomah County
#
#                                 3  \
# 0      Oregon: Summary level: 150
# 1      Oregon: Summary level: 150
# 2      Oregon: Summary level: 150
# 3      Oregon: Summary level: 150
# 4      Oregon: Summary level: 150
# ...                           ...
# 1092   Oregon: Summary level: 150
# 1093   Oregon: Summary level: 150
# 1094   Oregon: Summary level: 150
# 1095   Oregon: Summary level: 150
# 1096   Oregon: Summary level: 150
#
#                                                       4
# 0      state:41> county:017> tract:001600> block gro...
# 1      state:41> county:017> tract:001600> block gro...
# 2      state:41> county:017> tract:001700> block gro...
# 3      state:41> county:017> tract:001700> block gro...
# 4      state:41> county:017> tract:001700> block gro...
# ...                                                 ...
# 1092   state:41> county:051> tract:006702> block gro...
# 1093   state:41> county:051> tract:010500> block gro...
# 1094   state:41> county:051> tract:008201> block gro...
# 1095   state:41> county:051> tract:003200> block gro...
# 1096   state:41> county:051> tract:000402> block gro...
#
# [1097 rows x 5 columns]

# %%
acsdta_cln.columns = ['blkgrp', 'tract', 'cnty', 'sum', 'lis']

# %%
print(acsdta_cln)
# Out:
#              blkgrp                tract               cnty  \
# 0     Block Group 1      Census Tract 16   Deschutes County
# 1     Block Group 2      Census Tract 16   Deschutes County
# 2     Block Group 1      Census Tract 17   Deschutes County
# 3     Block Group 2      Census Tract 17   Deschutes County
# 4     Block Group 4      Census Tract 17   Deschutes County
# ...             ...                  ...                ...
# 1092  Block Group 2   Census Tract 67.02   Multnomah County
# 1093  Block Group 2     Census Tract 105   Multnomah County
# 1094  Block Group 1   Census Tract 82.01   Multnomah County
# 1095  Block Group 2      Census Tract 32   Multnomah County
# 1096  Block Group 3    Census Tract 4.02   Multnomah County
#
#                               sum  \
# 0      Oregon: Summary level: 150
# 1      Oregon: Summary level: 150
# 2      Oregon: Summary level: 150
# 3      Oregon: Summary level: 150
# 4      Oregon: Summary level: 150
# ...                           ...
# 1092   Oregon: Summary level: 150
# 1093   Oregon: Summary level: 150
# 1094   Oregon: Summary level: 150
# 1095   Oregon: Summary level: 150
# 1096   Oregon: Summary level: 150
#
#                                                     lis
# 0      state:41> county:017> tract:001600> block gro...
# 1      state:41> county:017> tract:001600> block gro...
# 2      state:41> county:017> tract:001700> block gro...
# 3      state:41> county:017> tract:001700> block gro...
# 4      state:41> county:017> tract:001700> block gro...
# ...                                                 ...
# 1092   state:41> county:051> tract:006702> block gro...
# 1093   state:41> county:051> tract:010500> block gro...
# 1094   state:41> county:051> tract:008201> block gro...
# 1095   state:41> county:051> tract:003200> block gro...
# 1096   state:41> county:051> tract:000402> block gro...
#
# [1097 rows x 5 columns]

# %%
acsdta_cln.drop(columns=['sum', 'lis'])
# Out:
#              blkgrp                tract               cnty
# 0     Block Group 1      Census Tract 16   Deschutes County
# 1     Block Group 2      Census Tract 16   Deschutes County
# 2     Block Group 1      Census Tract 17   Deschutes County
# 3     Block Group 2      Census Tract 17   Deschutes County
# 4     Block Group 4      Census Tract 17   Deschutes County
# ...             ...                  ...                ...
# 1092  Block Group 2   Census Tract 67.02   Multnomah County
# 1093  Block Group 2     Census Tract 105   Multnomah County
# 1094  Block Group 1   Census Tract 82.01   Multnomah County
# 1095  Block Group 2      Census Tract 32   Multnomah County
# 1096  Block Group 3    Census Tract 4.02   Multnomah County
#
# [1097 rows x 3 columns]

# %%
# Ok now join back to original

#acsdtafin = pd.concat([acs_dta, acsdta_cln], axis=1, ignore_index=True)
fin = pd.concat([acs_dta.reset_index(drop=True), acsdta_cln.reset_index(drop=False)], axis=1)

# %%
print(acsdtafin)
# Out:
#                                                       0      1     2     3  \
# 0     Block Group 1, Census Tract 16, Deschutes Coun...   50.0  20.0   874
# 1     Block Group 2, Census Tract 16, Deschutes Coun...  100.0  50.0  2271
# 2     Block Group 1, Census Tract 17, Deschutes Coun...  150.0  60.0  3118
# 3     Block Group 2, Census Tract 17, Deschutes Coun...  100.0  50.0  2370
# 4     Block Group 4, Census Tract 17, Deschutes Coun...   90.0  40.0  2228
# ...                                                 ...    ...   ...   ...
# 1092  Block Group 2, Census Tract 67.02, Multnomah C...  100.0  50.0  1049
# 1093  Block Group 2, Census Tract 105, Multnomah Cou...   90.0  40.0  1037
# 1094  Block Group 1, Census Tract 82.01, Multnomah C...  100.0  60.0   957
# 1095  Block Group 2, Census Tract 32, Multnomah Coun...  100.0  40.0  1189
# 1096  Block Group 3, Census Tract 4.02, Multnomah Co...  100.0  50.0  1424
#
#          4     5     6     7     8     9    10             11  \
# 0      586   288  32.9  31.0  57.0   874   374  Block Group 1
# 1     1089  1182  33.5  28.1  36.8  2271   979  Block Group 2
# 2     1374  1744  40.5  42.3  37.8  3118  1269  Block Group 1
# 3     1201  1169  37.2  34.3  39.7  2370  1026  Block Group 2
# 4      952  1276  32.8  37.6  30.2  2228   790  Block Group 4
# ...    ...   ...   ...   ...   ...   ...   ...            ...
# 1092   571   478  44.9  45.6  42.9  1049   441  Block Group 2
# 1093   416   621  46.8  52.0  45.1  1037   397  Block Group 2
# 1094   413   544  58.4  42.3  68.1   957   522  Block Group 1
# 1095   593   596  32.9  32.6  35.5  1189   433  Block Group 2
# 1096   615   809  31.9  29.9  33.6  1424   543  Block Group 3
#
#                        12                 13                           14  \
# 0         Census Tract 16   Deschutes County   Oregon: Summary level: 150
# 1         Census Tract 16   Deschutes County   Oregon: Summary level: 150
# 2         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# 3         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# 4         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# ...                   ...                ...                          ...
# 1092   Census Tract 67.02   Multnomah County   Oregon: Summary level: 150
# 1093     Census Tract 105   Multnomah County   Oregon: Summary level: 150
# 1094   Census Tract 82.01   Multnomah County   Oregon: Summary level: 150
# 1095      Census Tract 32   Multnomah County   Oregon: Summary level: 150
# 1096    Census Tract 4.02   Multnomah County   Oregon: Summary level: 150
#
#                                                      15
# 0      state:41> county:017> tract:001600> block gro...
# 1      state:41> county:017> tract:001600> block gro...
# 2      state:41> county:017> tract:001700> block gro...
# 3      state:41> county:017> tract:001700> block gro...
# 4      state:41> county:017> tract:001700> block gro...
# ...                                                 ...
# 1092   state:41> county:051> tract:006702> block gro...
# 1093   state:41> county:051> tract:010500> block gro...
# 1094   state:41> county:051> tract:008201> block gro...
# 1095   state:41> county:051> tract:003200> block gro...
# 1096   state:41> county:051> tract:000402> block gro...
#
# [1097 rows x 16 columns]

# %%
acsdtafin.head()
# Out:
#                                                    0      1     2     3     4  \
# 0  Block Group 1, Census Tract 16, Deschutes Coun...   50.0  20.0   874   586
# 1  Block Group 2, Census Tract 16, Deschutes Coun...  100.0  50.0  2271  1089
# 2  Block Group 1, Census Tract 17, Deschutes Coun...  150.0  60.0  3118  1374
# 3  Block Group 2, Census Tract 17, Deschutes Coun...  100.0  50.0  2370  1201
# 4  Block Group 4, Census Tract 17, Deschutes Coun...   90.0  40.0  2228   952
#
#       5     6     7     8     9    10             11                12  \
# 0   288  32.9  31.0  57.0   874   374  Block Group 1   Census Tract 16
# 1  1182  33.5  28.1  36.8  2271   979  Block Group 2   Census Tract 16
# 2  1744  40.5  42.3  37.8  3118  1269  Block Group 1   Census Tract 17
# 3  1169  37.2  34.3  39.7  2370  1026  Block Group 2   Census Tract 17
# 4  1276  32.8  37.6  30.2  2228   790  Block Group 4   Census Tract 17
#
#                   13                           14  \
# 0   Deschutes County   Oregon: Summary level: 150
# 1   Deschutes County   Oregon: Summary level: 150
# 2   Deschutes County   Oregon: Summary level: 150
# 3   Deschutes County   Oregon: Summary level: 150
# 4   Deschutes County   Oregon: Summary level: 150
#
#                                                   15
# 0   state:41> county:017> tract:001600> block gro...
# 1   state:41> county:017> tract:001600> block gro...
# 2   state:41> county:017> tract:001700> block gro...
# 3   state:41> county:017> tract:001700> block gro...
# 4   state:41> county:017> tract:001700> block gro...

# %%
print(fin)
# Out:
#                                              Unnamed: 0  unwt_tot_pop_count  \
# 0     Block Group 1, Census Tract 16, Deschutes Coun...                50.0
# 1     Block Group 2, Census Tract 16, Deschutes Coun...               100.0
# 2     Block Group 1, Census Tract 17, Deschutes Coun...               150.0
# 3     Block Group 2, Census Tract 17, Deschutes Coun...               100.0
# 4     Block Group 4, Census Tract 17, Deschutes Coun...                90.0
# ...                                                 ...                 ...
# 1092  Block Group 2, Census Tract 67.02, Multnomah C...               100.0
# 1093  Block Group 2, Census Tract 105, Multnomah Cou...                90.0
# 1094  Block Group 1, Census Tract 82.01, Multnomah C...               100.0
# 1095  Block Group 2, Census Tract 32, Multnomah Coun...               100.0
# 1096  Block Group 3, Census Tract 4.02, Multnomah Co...               100.0
#
#       tot_housing  tot_sex_age  tot_male  tot_female  tot_med_age  \
# 0            20.0          874       586         288         32.9
# 1            50.0         2271      1089        1182         33.5
# 2            60.0         3118      1374        1744         40.5
# 3            50.0         2370      1201        1169         37.2
# 4            40.0         2228       952        1276         32.8
# ...           ...          ...       ...         ...          ...
# 1092         50.0         1049       571         478         44.9
# 1093         40.0         1037       416         621         46.8
# 1094         60.0          957       413         544         58.4
# 1095         40.0         1189       593         596         32.9
# 1096         50.0         1424       615         809         31.9
#
#       med_age_male  med_age_female  tot_pop  hh_inc  index         blkgrp  \
# 0             31.0            57.0      874     374      0  Block Group 1
# 1             28.1            36.8     2271     979      1  Block Group 2
# 2             42.3            37.8     3118    1269      2  Block Group 1
# 3             34.3            39.7     2370    1026      3  Block Group 2
# 4             37.6            30.2     2228     790      4  Block Group 4
# ...            ...             ...      ...     ...    ...            ...
# 1092          45.6            42.9     1049     441   1092  Block Group 2
# 1093          52.0            45.1     1037     397   1093  Block Group 2
# 1094          42.3            68.1      957     522   1094  Block Group 1
# 1095          32.6            35.5     1189     433   1095  Block Group 2
# 1096          29.9            33.6     1424     543   1096  Block Group 3
#
#                     tract               cnty                          sum  \
# 0         Census Tract 16   Deschutes County   Oregon: Summary level: 150
# 1         Census Tract 16   Deschutes County   Oregon: Summary level: 150
# 2         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# 3         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# 4         Census Tract 17   Deschutes County   Oregon: Summary level: 150
# ...                   ...                ...                          ...
# 1092   Census Tract 67.02   Multnomah County   Oregon: Summary level: 150
# 1093     Census Tract 105   Multnomah County   Oregon: Summary level: 150
# 1094   Census Tract 82.01   Multnomah County   Oregon: Summary level: 150
# 1095      Census Tract 32   Multnomah County   Oregon: Summary level: 150
# 1096    Census Tract 4.02   Multnomah County   Oregon: Summary level: 150
#
#                                                     lis
# 0      state:41> county:017> tract:001600> block gro...
# 1      state:41> county:017> tract:001600> block gro...
# 2      state:41> county:017> tract:001700> block gro...
# 3      state:41> county:017> tract:001700> block gro...
# 4      state:41> county:017> tract:001700> block gro...
# ...                                                 ...
# 1092   state:41> county:051> tract:006702> block gro...
# 1093   state:41> county:051> tract:010500> block gro...
# 1094   state:41> county:051> tract:008201> block gro...
# 1095   state:41> county:051> tract:003200> block gro...
# 1096   state:41> county:051> tract:000402> block gro...
#
# [1097 rows x 17 columns]

# %%
dta_fin= fin.drop(columns=['Unnamed: 0 ', 'sum','lis'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-42eb1a9dccce> in <module>
# ----> 1 dta_fin= fin.drop(columns=['Unnamed: 0 ', 'sum','lis'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0 '] not found in axis"

# %%
fin.drop(['Unnamed: 0 , 'sum','lis'], axis=1, inplace=True)
# Out:
#   File "<ipython-input-51-4b96afb257e5>", line 1
#     fin.drop(['Unnamed: 0 , 'sum','lis'], axis=1, inplace=True)
#                                ^
# SyntaxError: invalid syntax

# %%
fin.head()
# Out:
#    unwt_tot_pop_count  tot_housing  tot_sex_age  tot_male  tot_female  \
# 0                50.0         20.0          874       586         288
# 1               100.0         50.0         2271      1089        1182
# 2               150.0         60.0         3118      1374        1744
# 3               100.0         50.0         2370      1201        1169
# 4                90.0         40.0         2228       952        1276
#
#    tot_med_age  med_age_male  med_age_female  tot_pop  hh_inc  index  \
# 0         32.9          31.0            57.0      874     374      0
# 1         33.5          28.1            36.8     2271     979      1
# 2         40.5          42.3            37.8     3118    1269      2
# 3         37.2          34.3            39.7     2370    1026      3
# 4         32.8          37.6            30.2     2228     790      4
#
#           blkgrp             tract               cnty  \
# 0  Block Group 1   Census Tract 16   Deschutes County
# 1  Block Group 2   Census Tract 16   Deschutes County
# 2  Block Group 1   Census Tract 17   Deschutes County
# 3  Block Group 2   Census Tract 17   Deschutes County
# 4  Block Group 4   Census Tract 17   Deschutes County
#
#                            sum  \
# 0   Oregon: Summary level: 150
# 1   Oregon: Summary level: 150
# 2   Oregon: Summary level: 150
# 3   Oregon: Summary level: 150
# 4   Oregon: Summary level: 150
#
#                                                  lis
# 0   state:41> county:017> tract:001600> block gro...
# 1   state:41> county:017> tract:001600> block gro...
# 2   state:41> county:017> tract:001700> block gro...
# 3   state:41> county:017> tract:001700> block gro...
# 4   state:41> county:017> tract:001700> block gro...

# %%
fin.to_csv('fin.csv', index=True)

# %%
acscln = pd.read_csv('fin.csv')
acscln.head()
# Out:
#    unwt_tot_pop_count  tot_housing  tot_sex_age  tot_male  tot_female  \
# 0                50.0         20.0          874       586         288
# 1               100.0         50.0         2271      1089        1182
# 2               150.0         60.0         3118      1374        1744
# 3               100.0         50.0         2370      1201        1169
# 4                90.0         40.0         2228       952        1276
#
#    tot_med_age  med_age_male  med_age_female  tot_pop  hh_inc         blkgrp  \
# 0         32.9          31.0            57.0      874     374  Block Group 1
# 1         33.5          28.1            36.8     2271     979  Block Group 2
# 2         40.5          42.3            37.8     3118    1269  Block Group 1
# 3         37.2          34.3            39.7     2370    1026  Block Group 2
# 4         32.8          37.6            30.2     2228     790  Block Group 4
#
#               tract               cnty
# 0   Census Tract 16   Deschutes County
# 1   Census Tract 16   Deschutes County
# 2   Census Tract 17   Deschutes County
# 3   Census Tract 17   Deschutes County
# 4   Census Tract 17   Deschutes County

# %%
# Now save out to .csv and move on to EDA

acscln.to_csv('acscln.csv', index=True)
