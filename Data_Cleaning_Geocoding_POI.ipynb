# %% [markdown]
# #### Geocoding and Data Cleaning POI
#
# Need to concat into one dataset and geocode to get lat/lon

# %%
import pandas as pd
import numpy as np
import io

# %%
#Latin characters. Need to use encoding below

salem=pd.read_csv("C:\\Users\\dlars\\Dropbox\\Data_Science\\Insight\\Project\\Insight_Data_Project\\salem_poi.csv",encoding='latin1')
bend=pd.read_csv("C:\\Users\\dlars\\Dropbox\\Data_Science\\Insight\\Project\\Insight_Data_Project\\bend_poi.csv",encoding='latin1')
eugene=pd.read_csv("C:\\Users\\dlars\\Dropbox\\Data_Science\\Insight\\Project\\Insight_Data_Project\\eugene_poi.csv",encoding='latin1')
portland=pd.read_csv("C:\\Users\\dlars\\Dropbox\\Data_Science\\Insight\\Project\\Insight_Data_Project\\portland_poi.csv",encoding='latin1')

# %%
salem.head()
# Out:
#                         poi                       address      city state  \
# 0              Salem Center             401 Center St. NE     Salem    OR
# 1    Willamette Town Center          831 Lancaster Dr. NE     Salem    OR
# 2  Woodburn Premium Outlets               1001 Arney Road  Woodburn    OR
# 3            Keizer Station  NE Corner I-5 And Chemawa Rd    Keizer    OR
# 4  Westgate Shopping Center             475 Taggart Dr NW     Salem    OR
#
#    zipcode
# 0    97301
# 1    97301
# 2    97071
# 3    97303
# 4    97304

# %%
bend.head()
# Out:
#                                poi                     address  city state  \
# 0                    Downtown Bend          916 NW Wall Street  Bend    OR
# 1                Old Mill District  450 SW Powerhouse Dr. #422  Bend    OR
# 2  Cascade Village Shopping Center              63455 N Hwy 97  Bend    OR
# 3              Bend Factory Stores              61334 S Hwy 97  Bend    OR
# 4             Bend River Promenade       3188 North Highway 97  Bend    OR
#
#    zipcode
# 0    97701
# 1    97702
# 2    97703
# 3    97702
# 4    97701

# %%
eugene.head()
# Out:
#                         poi                  address         city state  \
# 0  5th Street Public Market            296 E 5th Ave       Eugene    OR
# 1             Oakway Center         2350 Oakmont Way       Eugene    OR
# 2    The Shoppes at Gateway          3000 Gateway St  Springfield    OR
# 3       Valley River Center  293 Valley River Center       Eugene    OR
#
#    zipcode
# 0    97401
# 1    97401
# 2    97477
# 3    97401

# %%
portland.head()
# Out:
#                               poi                        address  \
# 0              BRIDGEPORT VILLAGE        7455 SW Bridgeport Road
# 1                 CASCADE STATION       9721 NE Cascades Parkway
# 2           CLACKAMAS TOWN CENTER           12000 SE 82nd Avenue
# 3            CEDAR HILLS CROSSING  3205 SW Cedar Hills Boulevard
# 4  COLUMBIA GORGE PREMIUM OUTLETS               450 NW 257th Way
#
#            city state  zipcode
# 0        Tigard    OR    97224
# 1      Portland    OR    97220
# 2  Happy Valley    OR    97086
# 3     Beaverton    OR    97005
# 4     Troutdale    OR    97060

# %%
#acsdtafin = pd.concat([acs_dta, acsdta_cln], axis=1, ignore_index=True)
#fin = pd.concat([acs_dta.reset_index(drop=True), acsdta_cln.reset_index(drop=False)], axis=1)
poi_master = pd.concat([bend, eugene, portland, salem])

# %%
print(poi_master)
# Out:
#                                 poi                         address  \
# 0                     Downtown Bend              916 NW Wall Street
# 1                 Old Mill District      450 SW Powerhouse Dr. #422
# 2   Cascade Village Shopping Center                  63455 N Hwy 97
# 3               Bend Factory Stores                  61334 S Hwy 97
# 4              Bend River Promenade           3188 North Highway 97
# 5             Forum Shopping Center                  2550 NE Hwy 20
# 6                NorthWest Crossing  2762 NW Crossing Dr. Suite 100
# 7           Brookswood Meadow Plaza      19570 Amber Meadow Dr #160
# 8                    Century Center                70 SW Century Dr
# 0          5th Street Public Market                   296 E 5th Ave
# 1                     Oakway Center                2350 Oakmont Way
# 2            The Shoppes at Gateway                 3000 Gateway St
# 3               Valley River Center         293 Valley River Center
# ...

# %%
poi_master
# Out:
#                                 poi                         address  \
# 0                     Downtown Bend              916 NW Wall Street
# 1                 Old Mill District      450 SW Powerhouse Dr. #422
# 2   Cascade Village Shopping Center                  63455 N Hwy 97
# 3               Bend Factory Stores                  61334 S Hwy 97
# 4              Bend River Promenade           3188 North Highway 97
# 5             Forum Shopping Center                  2550 NE Hwy 20
# 6                NorthWest Crossing  2762 NW Crossing Dr. Suite 100
# 7           Brookswood Meadow Plaza      19570 Amber Meadow Dr #160
# 8                    Century Center                70 SW Century Dr
# 0          5th Street Public Market                   296 E 5th Ave
# 1                     Oakway Center                2350 Oakmont Way
# 2            The Shoppes at Gateway                 3000 Gateway St
# 3               Valley River Center         293 Valley River Center
# ...

# %%
poi_master.reset_index(drop=True)
# Out:
#                                 poi                         address  \
# 0                     Downtown Bend              916 NW Wall Street
# 1                 Old Mill District      450 SW Powerhouse Dr. #422
# 2   Cascade Village Shopping Center                  63455 N Hwy 97
# 3               Bend Factory Stores                  61334 S Hwy 97
# 4              Bend River Promenade           3188 North Highway 97
# 5             Forum Shopping Center                  2550 NE Hwy 20
# 6                NorthWest Crossing  2762 NW Crossing Dr. Suite 100
# 7           Brookswood Meadow Plaza      19570 Amber Meadow Dr #160
# 8                    Century Center                70 SW Century Dr
# 9          5th Street Public Market                   296 E 5th Ave
# 10                    Oakway Center                2350 Oakmont Way
# 11           The Shoppes at Gateway                 3000 Gateway St
# 12              Valley River Center         293 Valley River Center
# ...

# %%
# Save out to .csv for now

poi_master.to_csv('poi_master.csv', index=True)

# %%
# Import geopandas package
import pandas as pd
import geopandas as gpd
import geopy

# %%
poi = pd.read_csv('poi_master.csv')

# %%
poi.head()
# Out:
#    Unnamed: 0                              poi                     address  \
# 0           0                    Downtown Bend          916 NW Wall Street
# 1           1                Old Mill District  450 SW Powerhouse Dr. #422
# 2           2  Cascade Village Shopping Center              63455 N Hwy 97
# 3           3              Bend Factory Stores              61334 S Hwy 97
# 4           4             Bend River Promenade       3188 North Highway 97
#
#    city state  zipcode
# 0  Bend    OR    97701
# 1  Bend    OR    97702
# 2  Bend    OR    97703
# 3  Bend    OR    97702
# 4  Bend    OR    97701

# %%
poi['cntry'] = 'USA'

# %%
poi.head()
# Out:
#    Unnamed: 0                              poi                     address  \
# 0           0                    Downtown Bend          916 NW Wall Street
# 1           1                Old Mill District  450 SW Powerhouse Dr. #422
# 2           2  Cascade Village Shopping Center              63455 N Hwy 97
# 3           3              Bend Factory Stores              61334 S Hwy 97
# 4           4             Bend River Promenade       3188 North Highway 97
#
#    city state  zipcode cntry
# 0  Bend    OR    97701   USA
# 1  Bend    OR    97702   USA
# 2  Bend    OR    97703   USA
# 3  Bend    OR    97702   USA
# 4  Bend    OR    97701   USA

# %%
#from geopy.geocoders import Nominatim

# %%
#nom = Nominatim(user_agent= 'myGeocoder')

# %%
poi['zipcode'] = poi['zipcode'].astype(str)
poi["address"] = poi["address"]+", "+poi["city"] +" , "+poi["state"]+ " , "+poi["zipcode"]+ " , "+poi["cntry"]

# %%
poi.head()
# Out:
#    Unnamed: 0                              poi  \
# 0           0                    Downtown Bend
# 1           1                Old Mill District
# 2           2  Cascade Village Shopping Center
# 3           3              Bend Factory Stores
# 4           4             Bend River Promenade
#
#                                              address  city state zipcode cntry
# 0        916 NW Wall Street, Bend , OR , 97701 , USA  Bend    OR   97701   USA
# 1  450 SW Powerhouse Dr. #422, Bend , OR , 97702 ...  Bend    OR   97702   USA
# 2            63455 N Hwy 97, Bend , OR , 97703 , USA  Bend    OR   97703   USA
# 3            61334 S Hwy 97, Bend , OR , 97702 , USA  Bend    OR   97702   USA
# 4     3188 North Highway 97, Bend , OR , 97701 , USA  Bend    OR   97701   USA

# %%
#poi["Coordinates"] = poi["address"].apply(nom.geocode)

# %%
poi.head()
# Out:
#    Unnamed: 0                              poi  \
# 0           0                    Downtown Bend
# 1           1                Old Mill District
# 2           2  Cascade Village Shopping Center
# 3           3              Bend Factory Stores
# 4           4             Bend River Promenade
#
#                                              address  city state zipcode  \
# 0  916 NW Wall Street, Bend , OR , USA, Bend , OR...  Bend    OR   97701
# 1  450 SW Powerhouse Dr. #422, Bend , OR , USA, B...  Bend    OR   97702
# 2  63455 N Hwy 97, Bend , OR , USA, Bend , OR , 9...  Bend    OR   97703
# 3  61334 S Hwy 97, Bend , OR , USA, Bend , OR , 9...  Bend    OR   97702
# 4  3188 North Highway 97, Bend , OR , USA, Bend ,...  Bend    OR   97701
#
#   cntry location point   latitude   longitude  altitude Coordinates
# 0   USA     None  None  43.396271 -124.226147       0.0        None
# 1   USA     None  None  44.045935 -121.315163       0.0        None
# ...

# %%
# It's timing out. Try something different

#from geopy.extra.rate_limiter import RateLimiter

# 1 - conveneint function to delay between geocoding calls
#geocode = RateLimiter(nom.geocode, min_delay_seconds=1)
# 2- - create location column
#poi['location'] = poi['address'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
#poi['point'] = poi['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
#poi[['latitude', 'longitude', 'altitude']] = pd.DataFrame(poi['point'].tolist(), index=poi.index)

# %%
# I think nominatim may be sensitive try google api

from geopy import geocoders
g = geocoders.GoogleV3(api_key='AIzaSyD2iwJSuieqGApnIjHQYG2TFyTe76ezMJM')

#create an input address string
#you can also build this by reading from an input database and building a string


#do the geocode
location = g.geocode(inputAddress, timeout=10)

#some things you can get from the result
print(location.latitude, location.longitude)
print(location.raw)
print(location.address)
